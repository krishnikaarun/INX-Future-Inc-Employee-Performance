# %% [markdown]
# ### Problem Statement:
#
#     The problem is to predict the performance rating of employees in a company based on various attributes such as age, gender, education background, job role, department, work experience, job satisfaction, etc. The goal is to build a machine learning classification model that can accurately predict the performance rating of employees and gain insights into the key factors influencing their performance.
#
# ### Dataset:
#
# The Dataset has 28 Columns and 1200 Rows.
#
# There are 12 Interger Columns. They are:
# 1) Age
#
# 2) DistanceFromHome
#
# 3) EmpHourlyRate
#
# 4) EmpJobLevel
#
# 5) NumCompaniesWorked
#
# 6) EmpLastSalaryHikePercent
#
# 7) TotalWorkExperienceInYears
#
# 8) TrainingTimesLastYear
#
# 9) ExperienceYearsAtThisCompany
#
# 10) ExperienceYearsInCurrentRole
#
# 11) YearsSinceLastPromotion
#
# 12) YearsWithCurrManager
#
# There are 16 Interger Columns. They are:
#
# 1) EmpNumber
#
# 2) Gender
#
# 3) EducationBackground
#
# 4) MaritalStatus
#
# 5) EmpDepartment
#
# 6) EmpJobRole
#
# 7) BusinessTravelFrequency
#
# 8) EmpEducationLevel
#
# 9) EmpEnvironmentSatisfaction
#
# 10) EmpJobInvolvement
#
# 11) EmpJobSatisfaction
#
# 12) OverTime
#
# 13) EmpRelationshipSatisfaction
#
# 14) EmpWorkLifeBalance
#
# 15) Attrition
#
# 16) PerformanceRating
#
# ### Data Preprocessing:
#
# The Pre-Processing steps involves:
#
# 1) Checking for Null values. **There was no Null values**
#
# 2) Checking for Duplicate values. **There was no Duplicate values**
#
# 3) Checking whether the data is Imbalanced. **The dataset is Imbalanced**
#
#         i) Used SMOTE(Synthetic Minority Over-sampling Technique) we have performed Oversampling as the dataset is small.
#
# ### Exploratory Data Analysis (EDA):
#
# Conducted an exploratory analysis of the data to understand its distribution, correlations, relationships between variables and Visualize key insights from the data.
#
# 1) Numerical features analysis
#
#     i) The Age distribution ranges from 18 to 60, but most of the employees are in between the range of 30 to 40 age.
#
#     ii) Most of the employees lives nearly 0 – 5 Kms or Miles from Office.
#
#     iii) Most of the employees work as low-level job in the Organization.
#
#     iv) The organization is mostly considered to be the second company for the Employees.
#
#     v) The company has offered minimum of 11% and Maximum of 25%, but most of the employee has received low percentage hike of 11- 14%.
#
#     vi) Most likely the employees are staying in this company for about 5 years.
#
#     vii) The employees undergo 2 – 3 training in the last year.
#
# 2) Categorical features Analysis
#
#     i) There are 60% of Male and 40% Female working in this Company.
#
#     ii) Most of the Employees are from Life Science and Medical Background.
#
#     iii) The Employees are mostly Working in Sale, Development, Research and Development Department and Least working Employees are from Data Science Department.
#
#     iv) Sale Executive and Developer are the top 2 departments where Employee count is high.
#
#     v) Most of the Employee’s work doesn’t involve travelling for work.
#
#     vi) Most of the Employee have completed their Bachelor degree.
#
#     vii) Most of the Employee’s Job Satisfaction, Environment Satisfaction and Job Involvement is High.
#
#     viii) 71% of Employees are not working Over Time.
#
#     ix) The 85% of employees are not having attrition in their work.
#
# 3) Correlation Analysis
#
#     i) EmpLastSalaryHikePercent, EmpDepartment,YearsSinceLastPromotion, ExperienceYearsInCurrentRole, YearsWithCurrManager, ExperienceYearsAtThisCompany are having the positive correlation when comparing to all features.
#
#     ii) EducationBackground, DistanceFromHome, TrainingTimesLastYear, BusinessTravelFrequency, OverTime are the features which are negatively correlate with the Perfomance Rating
#
#     iii) People who have more experience with the company has the more probability to get the promotion from the correlation between them.
#
# ### Feature Selection:
#
# We have Selected the most relevant features for modeling and remove any redundant or irrelevant ones. Techniques like SelectKBest,Chi Square are used individually for each model we used.
#
# ### Model Selection:
#
# We have Choosen appropriate classification algorithms for the task, such as Logistic Regression, Random Forest, Decision Trees, K-Nearest Neighbors, Navie Bayes from which best accuracy model will be selected.
#
# ### Model Building:
# We have Implemented the selected machine learning algorithms to create predictive models. Train the models on the training dataset.
#
# ### Hyperparameter Tuning:
#
# Fine-tuned the model hyperparameters using techniques like GridSearchCV and RandomizedSearchCV to optimize model performance.
#
# ### Model Evaluation:
#
# Evaluated the performance of the models using appropriate evaluation metrics such as accuracy, precision, recall, F1-score, and confusion matrix.
#
# Model Training and Evaluation We have tried with different models such as:
#
# 1) Logistic Regression (Accuracy – 85.01%)
#
# 2) **Random Forest Classifier** (Accuracy - **95%**)
#
# 3) Decision Tree Classifier (Accuracy - 92%)
#
# 4) KNN (Accuracy - 82%)
#
# 5) MultinomialNB (Accuracy - 60%)
#
# 6) GaussianNB (Accuracy - 91.6%)
#
# 7) BernoulliNB (Accuracy - 86%)
#
# # Random Forest Classifier gave us the higer Accuracy of 95%
